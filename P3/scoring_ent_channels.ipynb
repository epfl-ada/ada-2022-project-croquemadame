# %%
### IMPORTS ###
# import used libraries
import pandas as pd                        # pandas for data analysis
pd.options.mode.chained_assignment = None  # default='warn'
import matplotlib.pyplot as plt            # matplotlib for data visualisation

# %%
### PATHS ###

DIR = "../data/"

#read
TIMESERIES_PATH = DIR + "original_timeseries.tsv.gz" 
CHANNELS_PATH   = DIR + "original_channels.tsv.gz"

#write
PROCESSED_TIMESERIES_PATH = DIR + "processed_timeseries.tsv.zip"
SCORED_CHANNELS_PATH   = DIR + "scored_channels.tsv.zip"

# %%
### READS ###

timeseries = pd.read_csv(TIMESERIES_PATH, sep='\t')
channels   = pd.read_csv(CHANNELS_PATH, sep='\t')

#set dates format
timeseries['datetime'] = pd.to_datetime(timeseries['datetime'])
channels['join_date'] = pd.to_datetime(channels['join_date'])

# %% [markdown]
# ***
# ### Trying to see if there is any channels that started in 2015 with less than 10 videos

# %%
timeseries[(timeseries['videos'] <= 10) &
           (timeseries['category'] == 'Entertainment') &
           (timeseries['datetime'].dt.year == 2015)].drop_duplicates('channel')
# Out:
#                            channel       category   datetime        views  \
# 79948     UC0-3LtEFq7Hd_ydneEM8ErA  Entertainment 2015-12-28    11645.000
# 2898365   UCG5GX8MHxDCZdVWwEWm8Ijw  Entertainment 2015-07-13   481723.375
# 4077861   UCp7aooRhiGrdzfurH46aQnQ  Entertainment 2015-04-13  3574356.625
# 4680681   UCn42HkmbUavCnHhwnvwpl_g  Entertainment 2015-08-31   499510.900
# 12554736  UCxCMFuh1ie8_T7MKy_RqNmg  Entertainment 2015-12-07   396917.800
# 16910059  UC70zE3gJ2z8IW3Qtmj5TblA  Entertainment 2015-09-14    16912.750
# 17894937  UCQ9EMzXNjpHfWwp_bBzfGAg  Entertainment 2015-12-21    84026.750
#
#           delta_views      subs  delta_subs  videos  delta_videos  activity
# 79948           0.000     71.75         0.0       2             0         0
# 2898365      5631.375   3426.50         0.0       7             0         1
# 4077861     26739.625  12348.75         0.0       0             0         0
# 4680681     70617.900     96.40         0.0       0             0         0
# 12554736     4001.800   4809.00         0.0       6             0         0
# 16910059       45.750     82.00         0.0       1             0         0
# 17894937        4.750     32.00         0.0       3             0         0

# %%
### CHOOSE FOCUS CHANNELS ###

#compute the number of subs at the start of the period for each youtuber 
channels = pd.merge(channels,
                    timeseries.sort_values(by='datetime').drop_duplicates('channel')[['channel','subs']].rename(columns={"subs":"initial_subs"}),
                    on = 'channel')

#keep only channels that started in 2015 and are in the entertainment category (because timeseries starts in 2015) --> not succesful at all
ent_channels = channels[(channels['join_date'].dt.year == 2015) &
                        (channels['category_cc'] == 'Entertainment')]

#keep the intersection between the choosen channels and 
channel_ids = ent_channels[['channel']].drop_duplicates()
ent_timeseries = pd.merge(timeseries, channel_ids)
channel_ids = ent_timeseries[['channel']].drop_duplicates()
ent_channels = pd.merge(ent_channels, channel_ids)

# %% [markdown]
# ***

# %%
### CHOOSE FOCUS CHANNELS ###

#compute the number of subs at the start of the period for each youtuber 
channels = pd.merge(channels,
                    timeseries.sort_values(by='datetime').drop_duplicates('channel')[['channel','subs']].rename(columns={"subs":"initial_subs"}),
                    on = 'channel')

#keep only channels that started between 10k and 15k from the entertaining category
ent_channels = channels[(channels['initial_subs'] > 10e3) &
                        (channels['initial_subs'] < 15e3) &
                        (channels['category_cc'] == 'Entertainment')]

#keep the intersection between the choosen channels and 
channel_ids = ent_channels[['channel']].drop_duplicates()
ent_timeseries = pd.merge(timeseries, channel_ids)
channel_ids = ent_timeseries[['channel']].drop_duplicates()
ent_channels = pd.merge(ent_channels, channel_ids)

# %%
### SCORING CHANNELS ###

#compute the weekly growth for each channel in the timeseries
ent_timeseries['weekly_growth'] = ent_timeseries['delta_subs']/ent_timeseries['subs']

#compute the average growth score per channel
growth_score = ent_timeseries.groupby('channel').mean()['weekly_growth'].rename('growth_score')
ent_channels = pd.merge(ent_channels, growth_score, on='channel')

#keeps only 25% top and 25% bottom channels
top_channels = ent_channels.nlargest(int(len(ent_channels)*0.25), 'growth_score')[['channel','growth_score']]
bottom_channels = ent_channels.nsmallest(int(len(ent_channels)*0.25), 'growth_score')[['channel','growth_score']]
evo_channels = pd.concat([top_channels, bottom_channels]).sort_values('growth_score', ascending=False)
evo_channels['has_buzzed'] = 0 + 1 * (evo_channels['growth_score'] > bottom_channels['growth_score'].max())

ent_channels = pd.merge(ent_channels, evo_channels.drop(['growth_score'], axis=1), on='channel')
ent_timeseries = pd.merge(ent_timeseries, ent_channels[['channel', 'has_buzzed']], on='channel')

# %%
### SAVE PROCESSED DATA ###

ent_channels.to_csv(SCORED_CHANNELS_PATH, index=False, compression={'method':'zip'})
ent_timeseries.to_csv(PROCESSED_TIMESERIES_PATH, index=False, compression={'method':'zip'})

# %%
#sort ent_channels by growth_score
ent_channels = ent_channels.sort_values('growth_score', ascending=False)
ent_channels
# Out:
#         category_cc  join_date                   channel  \
# 556   Entertainment 2015-05-20  UCZy8KS02Jzl9kly5dQZ-fPA
# 719   Entertainment 2015-01-24  UCYUunpzH7_WtYwvss2Ja9GQ
# 665   Entertainment 2015-07-29  UCypdeKGOdPA6mma3z2Dzo9w
# 1188  Entertainment 2015-01-14  UC5Qa0ksDc4cE-RKHLcw5VDg
# 657   Entertainment 2015-08-09  UCCgHTlvBWzrMaL-15HjJX4A
# ...             ...        ...                       ...
# 59    Entertainment 2015-06-18  UC_17vC75UDfHgTJjX5Ravgw
# 1094  Entertainment 2015-07-21  UCH6PcEuNFkEUkbVTAdvWmFQ
# 380   Entertainment 2015-05-18  UCmn56iouEYh1XDCgAR5VKGg
# 911   Entertainment 2015-01-14  UCyHKikViYPiuniJCHUXKg5g
# 522   Entertainment 2015-05-11  UCRqLyzusAScljm1RH-SpdQQ
#
#                       name_cc  subscribers_cc  videos_cc  subscriber_rank_sb  \
# 556          Tobey in the MCU          103570         35            149536.0
# 719   Storytime With Reddi...           55600        348            247326.0
# 665                  J4CKSON7           52557         15            211760.0
# 1188              The Watcher           13100        198            757649.0
# 657             RANDOMLINK GH           70600         26            204594.0
# ...                       ...             ...        ...                 ...
# 59                      Jumbo         1730000        340              8418.0
# 1094            BLORANGETIGER           12800        123            626098.0
# 380                 Skye Crew          201015         49             91704.0
# 911                 Love Love           29952         32            404168.0
# 522           Toy Time Videos          127915         69            131175.0
#
#       weights  initial_subs  growth_score  has_buzzed
# 556    4.8220  5.308333e+02      0.250602           1
# 719    7.1410  1.318182e+02      0.203761           1
# 665    5.2955  1.585000e+02      0.171179           1
# 1188  12.0190  1.300000e+01      0.163399           1
# 657    5.8875  2.106278e+04      0.151052           1
# ...       ...           ...           ...         ...
# 59     2.5360  1.759949e+06      0.000145           0
# 1094  11.1550  1.237500e+02      0.000052           0
# 380    3.8570  2.140839e+05      0.000019           0
# 911    8.4425  3.076900e+04      0.000000           0
# 522    4.3545  1.280985e+05      0.000000           0
#
# [1312 rows x 11 columns]

# %%
#display timeseries from UCZy8KS02Jzl9kly5dQZ-fPA
ent_timeseries[ent_timeseries['channel'] == 'UCYUunpzH7_WtYwvss2Ja9GQ']
# Out:
#                          channel       category   datetime         views  \
# 167903  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-05-13  1.972455e+03
# 167904  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-05-20  2.836375e+03
# 167905  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-05-27  3.588000e+03
# 167906  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-06-03  7.078500e+03
# 167907  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-06-10  1.056900e+04
# 167908  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-06-17  2.753910e+04
# 167909  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-06-24  3.449130e+05
# 167910  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-07-01  1.593042e+06
# 167911  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-07-08  4.096587e+06
# 167912  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-07-15  7.095072e+06
# 167913  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-07-22  8.340985e+06
# 167914  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-07-29  1.222213e+07
# 167915  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-08-05  1.408450e+07
# 167916  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-08-12  1.655291e+07
# 167917  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-08-19  2.011407e+07
# 167918  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-08-26  2.324967e+07
# 167919  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-09-02  2.520185e+07
# 167920  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-09-09  2.744931e+07
# 167921  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-09-16  2.997188e+07
# 167922  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-09-23  3.205446e+07
# 167923  UCYUunpzH7_WtYwvss2Ja9GQ  Entertainment 2019-09-30  3.349753e+07
#
#          delta_views          subs   delta_subs  videos  delta_videos  \
# 167903  6.304545e+02    131.818182     0.000000       3             0
# 167904  8.639205e+02    135.250000     3.431818       3             0
# 167905  7.516250e+02    144.000000     8.750000       3             0
# 167906  3.490500e+03    154.500000    10.500000       6             3
# 167907  3.490500e+03    165.000000    10.500000      10             4
# 167908  1.697010e+04    223.800000    58.800000      18             8
# 167909  3.173739e+05    952.000000   728.200000      35            17
# 167910  1.248129e+06   3407.750000  2455.750000      65            30
# 167911  2.503545e+06   8279.750000  4872.000000      93            28
# 167912  2.998485e+06  14771.500000  6491.750000     111            18
# 167913  1.245913e+06  19248.000000  4476.500000     135            24
# 167914  3.881140e+06  24808.625000  5560.625000     162            27
# 167915  1.862380e+06  28609.000000  3800.375000     190            28
# 167916  2.468404e+06  32825.375000  4216.375000     217            27
# 167917  3.561166e+06  38680.500000  5855.125000     243            26
# 167918  3.135599e+06  43814.125000  5133.625000     269            26
# 167919  1.952179e+06  46876.750000  3062.625000     296            27
# 167920  2.247458e+06  50590.000000  3713.250000     319            23
# 167921  2.522573e+06  54517.000000  3927.000000     341            22
# 167922  2.082576e+06  57652.125000  3135.125000     361            20
# 167923  1.443075e+06  59642.857143  1990.732143     381            20
#
#         activity  weekly_growth  has_buzzed
# 167903         0       0.000000           1
# 167904         0       0.025374           1
# 167905         0       0.060764           1
# 167906         3       0.067961           1
# 167907         7       0.063636           1
# 167908        13       0.262735           1
# 167909        26       0.764916           1
# 167910        51       0.720637           1
# 167911        65       0.588424           1
# 167912        55       0.439478           1
# 167913        49       0.232570           1
# 167914        57       0.224141           1
# 167915        62       0.132838           1
# 167916        63       0.128449           1
# 167917        61       0.151371           1
# 167918        60       0.117168           1
# 167919        60       0.065334           1
# 167920        57       0.073399           1
# 167921        53       0.072033           1
# 167922        48       0.054380           1
# 167923        46       0.033378           1
