# %%
### IMPORTS ###
# import used libraries
import pandas as pd                        # pandas for data analysis
pd.options.mode.chained_assignment = None  # default='warn'
import matplotlib.pyplot as plt            # matplotlib for data visualisation

# %%
### PATHS ###

DIR = "../data/"

#read
TIMESERIES_PATH = DIR + "original_timeseries.tsv.gz" 
CHANNELS_PATH   = DIR + "original_channels.tsv.gz"

#write
PROCESSED_TIMESERIES_PATH = DIR + "processed_timeseries.tsv.zip"
SCORED_CHANNELS_PATH   = DIR + "scored_channels.tsv.zip"

# %%
### READS ###

timeseries = pd.read_csv(TIMESERIES_PATH, sep='\t')
channels   = pd.read_csv(CHANNELS_PATH, sep='\t')

#set dates format
timeseries['datetime'] = pd.to_datetime(timeseries['datetime'])
channels['join_date'] = pd.to_datetime(channels['join_date'])

# %% [markdown]
# ***
# ### Trying to see if there is any channels that started in 2015 with less than 10 videos

# %%
channels_2016 = timeseries.drop_duplicates('channel')[((timeseries['datetime'].dt.year == 2016) | 
                                                       (timeseries['datetime'].dt.year == 2015)) &
                                                      (timeseries['videos'] <= 10)].channel

#compute the number of subs at the start of the period for each youtuber 
channels = pd.merge(channels,
                    timeseries.sort_values(by='datetime').drop_duplicates('channel')[['channel','subs']].rename(columns={"subs":"initial_subs"}),
                    on = 'channel')

ent_channels = pd.merge(channels[channels.category_cc == 'Entertainment'], channels_2016)
ent_timeseries = pd.merge(timeseries, ent_channels.drop_duplicates('channel').channel)
# Out:
# C:\Users\pujol\AppData\Local\Temp\ipykernel_40808\3405160264.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   channels_2016 = timeseries.drop_duplicates('channel')[((timeseries['datetime'].dt.year == 2016) |

# %%
ent_channels
ent_timeseries.drop_duplicates('channel')
# Out:
#                          channel       category   datetime         views  \
# 0       UC4mvN14nN07FKzBRRAngqvA  Entertainment 2016-03-21  2.843375e+03
# 184     UC2V1ul4ul85kac0Y81wXTqQ  Entertainment 2016-08-15  4.025000e+02
# 347     UCm3jfzwwDCMb33AOsbLgnng  Entertainment 2016-02-22  4.336350e+05
# 535     UCeVWCgg-6XlDIjWJlrRnqYQ  Entertainment 2016-08-01  4.774485e+05
# 700     UCxMvjumCHLs5bZv0ISmClPg  Entertainment 2016-08-15  1.251590e+05
# ...                          ...            ...        ...           ...
# 487353  UClRCyBAc8e-1bjE7jP620sg  Entertainment 2016-12-05  2.645000e+04
# 487501  UCEJpGxMVHCltUzIAMb8J4vQ  Entertainment 2016-09-19  1.461949e+05
# 487598  UCNLReGxOCGDExjb7pjPuPcA  Entertainment 2016-10-10  1.314013e+08
# 487741  UCnFpajlezRfiOMdw8Tt3z5A  Entertainment 2016-10-10  1.003384e+08
# 487897  UCAkY2Lgpx4KGsY7LGCr6MBA  Entertainment 2016-04-18  7.281000e+03
#
#         delta_views        subs  delta_subs  videos  delta_videos  activity
# 0           984.375     359.125         0.0       0             0         0
# 184           0.000     186.250         0.0       0             0         0
# 347         557.000     316.250         0.0       1             0         0
# 535        2282.500    4813.250         0.0       9             0         1
# 700           0.000     669.000         0.0       0             0         0
# ...             ...         ...         ...     ...           ...       ...
# 487353        0.000     541.000         0.0       9             0         5
# 487501   146194.875   17489.000         0.0       0             0         0
# 487598        0.000  130447.000         0.0       0             0         0
# 487741        0.000  116982.000         0.0       0             0         0
# 487897       81.000     137.750         0.0       5             0         0
#
# [3050 rows x 10 columns]

# %%
### CHOOSE FOCUS CHANNELS ###

#compute the number of subs at the start of the period for each youtuber 
channels = pd.merge(channels,
                    timeseries.sort_values(by='datetime').drop_duplicates('channel')[['channel','subs']].rename(columns={"subs":"initial_subs"}),
                    on = 'channel')

#keep only channels that started in 2015 and are in the entertainment category (because timeseries starts in 2015) --> not succesful at all
ent_channels = channels[(channels['join_date'].dt.year == 2015) &
                        (channels['category_cc'] == 'Entertainment')]

#keep the intersection between the choosen channels and 
channel_ids = ent_channels[['channel']].drop_duplicates()
ent_timeseries = pd.merge(timeseries, channel_ids)
channel_ids = ent_timeseries[['channel']].drop_duplicates()
ent_channels = pd.merge(ent_channels, channel_ids)

# %% [markdown]
# ***

# %%
### CHOOSE FOCUS CHANNELS ###

#compute the number of subs at the start of the period for each youtuber 
channels = pd.merge(channels,
                    timeseries.sort_values(by='datetime').drop_duplicates('channel')[['channel','subs']].rename(columns={"subs":"initial_subs"}),
                    on = 'channel')

#keep only channels that started between 10k and 15k from the entertaining category
ent_channels = channels[(channels['initial_subs'] > 10e3) &
                        (channels['initial_subs'] < 15e3) &
                        (channels['category_cc'] == 'Entertainment')]

#keep the intersection between the choosen channels and 
channel_ids = ent_channels[['channel']].drop_duplicates()
ent_timeseries = pd.merge(timeseries, channel_ids)
channel_ids = ent_timeseries[['channel']].drop_duplicates()
ent_channels = pd.merge(ent_channels, channel_ids)

# %%
### SCORING CHANNELS ###

#compute the weekly growth for each channel in the timeseries
ent_timeseries['weekly_growth'] = ent_timeseries['delta_subs']/ent_timeseries['subs']

#compute the average growth score per channel
growth_score = ent_timeseries.groupby('channel').mean()['weekly_growth'].rename('growth_score')
ent_channels = pd.merge(ent_channels, growth_score, on='channel')

#keeps only 25% top and 25% bottom channels
top_channels = ent_channels.nlargest(int(len(ent_channels)*0.25), 'growth_score')[['channel','growth_score']]
bottom_channels = ent_channels.nsmallest(int(len(ent_channels)*0.25), 'growth_score')[['channel','growth_score']]
evo_channels = pd.concat([top_channels, bottom_channels]).sort_values('growth_score', ascending=False)
evo_channels['has_buzzed'] = 0 + 1 * (evo_channels['growth_score'] > bottom_channels['growth_score'].max())

ent_channels = pd.merge(ent_channels, evo_channels.drop(['growth_score'], axis=1), on='channel')
ent_timeseries = pd.merge(ent_timeseries, ent_channels[['channel', 'has_buzzed']], on='channel')

# %%
### SAVE PROCESSED DATA ###

ent_channels.to_csv(SCORED_CHANNELS_PATH, index=False, compression={'method':'zip'})
ent_timeseries.to_csv(PROCESSED_TIMESERIES_PATH, index=False, compression={'method':'zip'})

# %%
#sort ent_channels by growth_score
ent_channels = ent_channels.sort_values('growth_score', ascending=False)
ent_channels
# Out:
#         category_cc  join_date                   channel              name_cc  \
# 441   Entertainment 2016-08-12  UCpeX7ds2tTpiRMwga0jUq8g       The LEGO Group
# 1300  Entertainment 2016-02-02  UCHOVHGRniakvAx0AaziVCGA  HollywoodHereICome!
# 901   Entertainment 2016-10-08  UCOxBUBKIrtxrUEWgl9KQluA            Crypto PM
# 142   Entertainment 2016-07-29  UClguIWOD4hs4vHYBLRZJiVA       Music For Kids
# 1127  Entertainment 2016-10-03  UCsfYsJT_LvMZnJux8nSlIgg       Kids Toys Tube
# ...             ...        ...                       ...                  ...
# 1430  Entertainment 2014-08-17  UCEYgGr0ry9I5dYTqyibURnw         TopRamenOnly
# 511   Entertainment 2015-05-18  UCmn56iouEYh1XDCgAR5VKGg            Skye Crew
# 391   Entertainment 2011-10-04  UCdSr4xliU8yDyS1aGnCUMTA      Sam Pepper Live
# 835   Entertainment 2012-07-13  UCOOQeCTjRQXvP-5s2U7v5Gg      Satisfying Pill
# 1207  Entertainment 2012-08-25  UCfo-3S9rAR6MY5lxa5EV5Eg           Mahel Khan
#
#       subscribers_cc  videos_cc  subscriber_rank_sb  weights  initial_subs  \
# 441           244000         66             73829.0   3.7770       161.750
# 1300           19233         84            609995.0   9.1900      3907.250
# 901            58400        223            246868.0   7.1165        10.000
# 142          1070000        152             15647.0   2.8240        10.500
# 1127           33900         43            397565.0   6.6785        81.500
# ...              ...        ...                 ...      ...           ...
# 1430           13400         22            793763.0  10.3330     15326.000
# 511           201015         49             91704.0   3.8570    214083.875
# 391           316218         11             58088.0   3.5535    316133.500
# 835            73434         28            206624.0   6.1515     93179.750
# 1207           24800         70            501547.0   6.2025     24680.000
#
#       growth_score  has_buzzed
# 441       0.174242           1
# 1300      0.139361           1
# 901       0.126646           1
# 142       0.099742           1
# 1127      0.090263           1
# ...            ...         ...
# 1430      0.000020           0
# 511       0.000019           0
# 391       0.000014           0
# 835       0.000000           0
# 1207      0.000000           0
#
# [1524 rows x 11 columns]

# %%
#display timeseries from UCZy8KS02Jzl9kly5dQZ-fPA
ent_timeseries[ent_timeseries['channel'] == 'UCHOVHGRniakvAx0AaziVCGA']
# Out:
#                          channel       category   datetime         views  \
# 138417  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-07-18  3.077045e+06
# 138418  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-07-25  4.300321e+06
# 138419  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-08-01  6.402899e+06
# 138420  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-08-08  8.074860e+06
# 138421  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-08-15  1.003531e+07
# 138422  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-08-22  1.199210e+07
# 138423  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-08-29  1.410706e+07
# 138424  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-09-05  1.678187e+07
# 138425  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-09-12  1.985693e+07
# 138426  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-09-19  2.231501e+07
# 138427  UCHOVHGRniakvAx0AaziVCGA  Entertainment 2016-09-26  2.442707e+07
#
#         delta_views       subs  delta_subs  videos  delta_videos  activity  \
# 138417   174753.750   3907.250       0.000       2             0         2
# 138418  1223276.250   5295.000    1387.750       2             0         2
# 138419  2102577.750   7132.500    1837.500       2             0         0
# 138420  1671961.500   8814.000    1681.500       2             0         0
# 138421  1960446.500  10468.250    1654.250       2             0         0
# 138422  1956794.750  12026.500    1558.250       2             0         0
# 138423  2114955.500  13732.500    1706.000       2             0         0
# 138424  2674816.500  15833.500    2101.000       2             0         0
# 138425  3075053.625  18089.500    2256.000       3             1         1
# 138426  2458078.875  19738.000    1648.500       3             0         1
# 138427  2112065.375  21217.625    1479.625       3             0         0
#
#         weekly_growth  has_buzzed
# 138417       0.000000           1
# 138418       0.262087           1
# 138419       0.257624           1
# 138420       0.190776           1
# 138421       0.158025           1
# 138422       0.129568           1
# 138423       0.124231           1
# 138424       0.132693           1
# 138425       0.124713           1
# 138426       0.083519           1
# 138427       0.069736           1
